# %% [markdown]
# ### Install Python Packages

# %%
### Create or update your local Python environment

# %pip install azure-functions
# %pip install azure-core
# %pip install azure-cosmos
# %pip install openai
# %pip install numpy
# %pip install requests
# %pip install pandas
# %pip install azure-storage-blob 
# %pip install azure-identity
# %pip install smart_open
# %pip install tenacity
# %pip install pinecone-client
# %pip install redis
# %pip install tiktoken
# %pip install azure-storage-file-share
# %pip install python-dotenv
# %pip install azure-search-documents==11.4.0b3
# %pip install azure-ai-formrecognizer
# %pip install beautifulsoup4
# %pip install lxml
# %pip install openpyxl
# %pip install azure-ai-textanalytics
# %pip install langchain==0.0.139
# %pip install flask
# %pip install flask-socketio
# Out:
# Requirement already satisfied: azure-functions in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (1.14.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: azure-core in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (1.27.0)
# Requirement already satisfied: requests>=2.18.4 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from azure-core) (2.31.0)
# Requirement already satisfied: six>=1.11.0 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from azure-core) (1.16.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from azure-core) (4.6.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.18.4->azure-core) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.18.4->azure-core) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.18.4->azure-core) (2.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.18.4->azure-core) (2023.5.7)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: azure-cosmos in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (4.3.1)
# Requirement already satisfied: azure-core<2.0.0,>=1.23.0 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from azure-cosmos) (1.27.0)
# Requirement already satisfied: requests>=2.18.4 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from azure-core<2.0.0,>=1.23.0->azure-cosmos) (2.31.0)
# Requirement already satisfied: six>=1.11.0 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from azure-core<2.0.0,>=1.23.0->azure-cosmos) (1.16.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from azure-core<2.0.0,>=1.23.0->azure-cosmos) (4.6.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.23.0->azure-cosmos) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.23.0->azure-cosmos) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.23.0->azure-cosmos) (2.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.23.0->azure-cosmos) (2023.5.7)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: openai in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (0.27.7)
# Requirement already satisfied: requests>=2.20 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from openai) (2.31.0)
# Requirement already satisfied: tqdm in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from openai) (4.65.0)
# Requirement already satisfied: aiohttp in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from openai) (3.8.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.20->openai) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.20->openai) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.20->openai) (2.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.20->openai) (2023.5.7)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from aiohttp->openai) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from aiohttp->openai) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from aiohttp->openai) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from aiohttp->openai) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from aiohttp->openai) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from aiohttp->openai) (1.3.1)
# Requirement already satisfied: colorama in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from tqdm->openai) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: numpy in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (1.24.3)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: requests in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from requests) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from requests) (2.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from requests) (2023.5.7)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from pandas) (1.24.3)
# Requirement already satisfied: six>=1.5 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: azure-storage-blob in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (12.16.0)
# Requirement already satisfied: azure-core<2.0.0,>=1.26.0 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from azure-storage-blob) (1.27.0)
# Requirement already satisfied: cryptography>=2.1.4 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from azure-storage-blob) (41.0.1)
# Requirement already satisfied: typing-extensions>=4.0.1 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from azure-storage-blob) (4.6.3)
# Requirement already satisfied: isodate>=0.6.1 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from azure-storage-blob) (0.6.1)
# Requirement already satisfied: requests>=2.18.4 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from azure-core<2.0.0,>=1.26.0->azure-storage-blob) (2.31.0)
# Requirement already satisfied: six>=1.11.0 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from azure-core<2.0.0,>=1.26.0->azure-storage-blob) (1.16.0)
# Requirement already satisfied: cffi>=1.12 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from cryptography>=2.1.4->azure-storage-blob) (1.15.1)
# Requirement already satisfied: pycparser in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from cffi>=1.12->cryptography>=2.1.4->azure-storage-blob) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.26.0->azure-storage-blob) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.26.0->azure-storage-blob) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.26.0->azure-storage-blob) (2.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.26.0->azure-storage-blob) (2023.5.7)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: azure-identity in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (1.13.0)
# Requirement already satisfied: azure-core<2.0.0,>=1.11.0 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from azure-identity) (1.27.0)
# Requirement already satisfied: cryptography>=2.5 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from azure-identity) (41.0.1)
# Requirement already satisfied: msal<2.0.0,>=1.20.0 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from azure-identity) (1.22.0)
# Requirement already satisfied: msal-extensions<2.0.0,>=0.3.0 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from azure-identity) (1.0.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from azure-identity) (1.16.0)
# Requirement already satisfied: requests>=2.18.4 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from azure-core<2.0.0,>=1.11.0->azure-identity) (2.31.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from azure-core<2.0.0,>=1.11.0->azure-identity) (4.6.3)
# Requirement already satisfied: cffi>=1.12 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from cryptography>=2.5->azure-identity) (1.15.1)
# Requirement already satisfied: PyJWT[crypto]<3,>=1.0.0 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from msal<2.0.0,>=1.20.0->azure-identity) (2.7.0)
# Requirement already satisfied: portalocker<3,>=1.6 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from msal-extensions<2.0.0,>=0.3.0->azure-identity) (2.7.0)
# Requirement already satisfied: pycparser in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from cffi>=1.12->cryptography>=2.5->azure-identity) (2.21)
# Requirement already satisfied: pywin32>=226 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from portalocker<3,>=1.6->msal-extensions<2.0.0,>=0.3.0->azure-identity) (306)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.11.0->azure-identity) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.11.0->azure-identity) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.11.0->azure-identity) (2.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.11.0->azure-identity) (2023.5.7)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: smart_open in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (6.3.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: tenacity in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (8.2.2)Note: you may need to restart the kernel to use updated packages.
#
# Collecting pinecone-clientNote: you may need to restart the kernel to use updated packages.
#
#   Downloading pinecone_client-2.2.2-py3-none-any.whl (179 kB)
#                                               0.0/179.1 kB ? eta -:--:--
#      -------------------------------------- 179.1/179.1 kB 5.4 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.19.0 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from pinecone-client) (2.31.0)
# Requirement already satisfied: pyyaml>=5.4 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from pinecone-client) (6.0)
# Collecting loguru>=0.5.0 (from pinecone-client)
#   Using cached loguru-0.7.0-py3-none-any.whl (59 kB)
# Requirement already satisfied: typing-extensions>=3.7.4 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from pinecone-client) (4.6.3)
# Requirement already satisfied: dnspython>=2.0.0 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from pinecone-client) (2.3.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from pinecone-client) (2.8.2)
# Requirement already satisfied: urllib3>=1.21.1 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from pinecone-client) (2.0.2)
# Requirement already satisfied: tqdm>=4.64.1 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from pinecone-client) (4.65.0)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from pinecone-client) (1.24.3)
# Requirement already satisfied: colorama>=0.3.4 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from loguru>=0.5.0->pinecone-client) (0.4.6)
# Collecting win32-setctime>=1.0.0 (from loguru>=0.5.0->pinecone-client)
#   Using cached win32_setctime-1.1.0-py3-none-any.whl (3.6 kB)
# Requirement already satisfied: six>=1.5 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.5.3->pinecone-client) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.19.0->pinecone-client) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.19.0->pinecone-client) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.19.0->pinecone-client) (2023.5.7)
# Installing collected packages: win32-setctime, loguru, pinecone-client
# Successfully installed loguru-0.7.0 pinecone-client-2.2.2 win32-setctime-1.1.0
# Requirement already satisfied: redis in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (4.5.5)
# Requirement already satisfied: async-timeout>=4.0.2 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from redis) (4.0.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: tiktoken in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (0.4.0)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from tiktoken) (2023.6.3)
# Requirement already satisfied: requests>=2.26.0 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from tiktoken) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.26.0->tiktoken) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.26.0->tiktoken) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.26.0->tiktoken) (2.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.26.0->tiktoken) (2023.5.7)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: azure-storage-file-share in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (12.12.0)
# Requirement already satisfied: azure-core<2.0.0,>=1.26.0 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from azure-storage-file-share) (1.27.0)
# Requirement already satisfied: cryptography>=2.1.4 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from azure-storage-file-share) (41.0.1)
# Requirement already satisfied: typing-extensions>=4.0.1 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from azure-storage-file-share) (4.6.3)
# Requirement already satisfied: isodate>=0.6.1 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from azure-storage-file-share) (0.6.1)
# Requirement already satisfied: requests>=2.18.4 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from azure-core<2.0.0,>=1.26.0->azure-storage-file-share) (2.31.0)
# Requirement already satisfied: six>=1.11.0 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from azure-core<2.0.0,>=1.26.0->azure-storage-file-share) (1.16.0)
# Requirement already satisfied: cffi>=1.12 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from cryptography>=2.1.4->azure-storage-file-share) (1.15.1)
# Requirement already satisfied: pycparser in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from cffi>=1.12->cryptography>=2.1.4->azure-storage-file-share) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.26.0->azure-storage-file-share) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.26.0->azure-storage-file-share) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.26.0->azure-storage-file-share) (2.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.26.0->azure-storage-file-share) (2023.5.7)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: python-dotenv in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (1.0.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: azure-search-documents==11.4.0b3 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (11.4.0b3)
# Requirement already satisfied: azure-core<2.0.0,>=1.24.0 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from azure-search-documents==11.4.0b3) (1.27.0)
# Requirement already satisfied: azure-common~=1.1 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from azure-search-documents==11.4.0b3) (1.1.28)
# Requirement already satisfied: isodate>=0.6.0 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from azure-search-documents==11.4.0b3) (0.6.1)
# Requirement already satisfied: requests>=2.18.4 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from azure-core<2.0.0,>=1.24.0->azure-search-documents==11.4.0b3) (2.31.0)
# Requirement already satisfied: six>=1.11.0 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from azure-core<2.0.0,>=1.24.0->azure-search-documents==11.4.0b3) (1.16.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from azure-core<2.0.0,>=1.24.0->azure-search-documents==11.4.0b3) (4.6.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.24.0->azure-search-documents==11.4.0b3) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.24.0->azure-search-documents==11.4.0b3) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.24.0->azure-search-documents==11.4.0b3) (2.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.24.0->azure-search-documents==11.4.0b3) (2023.5.7)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: azure-ai-formrecognizer in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (3.2.1)
# Requirement already satisfied: azure-core<2.0.0,>=1.23.0 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from azure-ai-formrecognizer) (1.27.0)
# Requirement already satisfied: msrest>=0.6.21 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from azure-ai-formrecognizer) (0.7.1)
# Requirement already satisfied: azure-common~=1.1 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from azure-ai-formrecognizer) (1.1.28)
# Requirement already satisfied: typing-extensions>=4.0.1 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from azure-ai-formrecognizer) (4.6.3)
# Requirement already satisfied: requests>=2.18.4 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from azure-core<2.0.0,>=1.23.0->azure-ai-formrecognizer) (2.31.0)
# Requirement already satisfied: six>=1.11.0 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from azure-core<2.0.0,>=1.23.0->azure-ai-formrecognizer) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from msrest>=0.6.21->azure-ai-formrecognizer) (2023.5.7)
# Requirement already satisfied: isodate>=0.6.0 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from msrest>=0.6.21->azure-ai-formrecognizer) (0.6.1)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from msrest>=0.6.21->azure-ai-formrecognizer) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.23.0->azure-ai-formrecognizer) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.23.0->azure-ai-formrecognizer) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.23.0->azure-ai-formrecognizer) (2.0.2)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from requests-oauthlib>=0.5.0->msrest>=0.6.21->azure-ai-formrecognizer) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: beautifulsoup4 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from beautifulsoup4) (2.4.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: lxml in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (4.9.2)
# Note: you may need to restart the kernel to use updated packages.
# Collecting openpyxl
#   Using cached openpyxl-3.1.2-py2.py3-none-any.whl (249 kB)
# Collecting et-xmlfile (from openpyxl)
#   Using cached et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.1.2
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: azure-ai-textanalytics in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (5.2.1)
# Requirement already satisfied: azure-core<2.0.0,>=1.24.0 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from azure-ai-textanalytics) (1.27.0)
# Requirement already satisfied: msrest>=0.7.0 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from azure-ai-textanalytics) (0.7.1)
# Requirement already satisfied: azure-common~=1.1 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from azure-ai-textanalytics) (1.1.28)
# Requirement already satisfied: typing-extensions>=4.0.1 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from azure-ai-textanalytics) (4.6.3)
# Requirement already satisfied: requests>=2.18.4 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from azure-core<2.0.0,>=1.24.0->azure-ai-textanalytics) (2.31.0)
# Requirement already satisfied: six>=1.11.0 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from azure-core<2.0.0,>=1.24.0->azure-ai-textanalytics) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from msrest>=0.7.0->azure-ai-textanalytics) (2023.5.7)
# Requirement already satisfied: isodate>=0.6.0 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from msrest>=0.7.0->azure-ai-textanalytics) (0.6.1)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from msrest>=0.7.0->azure-ai-textanalytics) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.24.0->azure-ai-textanalytics) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.24.0->azure-ai-textanalytics) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.24.0->azure-ai-textanalytics) (2.0.2)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from requests-oauthlib>=0.5.0->msrest>=0.7.0->azure-ai-textanalytics) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: langchain==0.0.139 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (0.0.139)
# Requirement already satisfied: PyYAML>=5.4.1 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from langchain==0.0.139) (6.0)
# Requirement already satisfied: SQLAlchemy<2,>=1 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from langchain==0.0.139) (1.4.48)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from langchain==0.0.139) (3.8.4)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from langchain==0.0.139) (4.0.2)
# Requirement already satisfied: dataclasses-json<0.6.0,>=0.5.7 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from langchain==0.0.139) (0.5.7)
# Requirement already satisfied: gptcache>=0.1.7 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from langchain==0.0.139) (0.1.29.1)
# Requirement already satisfied: numpy<2,>=1 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from langchain==0.0.139) (1.24.3)
# Requirement already satisfied: openapi-schema-pydantic<2.0,>=1.2 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from langchain==0.0.139) (1.2.4)
# Requirement already satisfied: pydantic<2,>=1 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from langchain==0.0.139) (1.10.8)
# Requirement already satisfied: requests<3,>=2 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from langchain==0.0.139) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from langchain==0.0.139) (8.2.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.139) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.139) (3.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.139) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.139) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.139) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.139) (1.3.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.3.0 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain==0.0.139) (3.19.0)
# Requirement already satisfied: marshmallow-enum<2.0.0,>=1.5.1 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain==0.0.139) (1.5.1)
# Requirement already satisfied: typing-inspect>=0.4.0 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain==0.0.139) (0.9.0)
# Requirement already satisfied: cachetools in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from gptcache>=0.1.7->langchain==0.0.139) (5.3.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from pydantic<2,>=1->langchain==0.0.139) (4.6.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2->langchain==0.0.139) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2->langchain==0.0.139) (2.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2->langchain==0.0.139) (2023.5.7)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from SQLAlchemy<2,>=1->langchain==0.0.139) (2.0.2)
# Requirement already satisfied: packaging>=17.0 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from marshmallow<4.0.0,>=3.3.0->dataclasses-json<0.6.0,>=0.5.7->langchain==0.0.139) (23.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from typing-inspect>=0.4.0->dataclasses-json<0.6.0,>=0.5.7->langchain==0.0.139) (1.0.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: flask in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (2.3.2)
# Requirement already satisfied: Werkzeug>=2.3.3 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from flask) (2.3.4)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from flask) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from flask) (2.1.2)
# Requirement already satisfied: click>=8.1.3 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from flask) (8.1.3)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from flask) (1.6.2)
# Requirement already satisfied: colorama in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from click>=8.1.3->flask) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from Jinja2>=3.1.2->flask) (2.1.3)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: flask-socketio in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (5.3.4)
# Requirement already satisfied: Flask>=0.9 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from flask-socketio) (2.3.2)
# Requirement already satisfied: python-socketio>=5.0.2 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from flask-socketio) (5.8.0)
# Requirement already satisfied: Werkzeug>=2.3.3 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from Flask>=0.9->flask-socketio) (2.3.4)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from Flask>=0.9->flask-socketio) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from Flask>=0.9->flask-socketio) (2.1.2)
# Requirement already satisfied: click>=8.1.3 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from Flask>=0.9->flask-socketio) (8.1.3)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from Flask>=0.9->flask-socketio) (1.6.2)
# Requirement already satisfied: bidict>=0.21.0 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from python-socketio>=5.0.2->flask-socketio) (0.22.1)
# Requirement already satisfied: python-engineio>=4.3.0 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from python-socketio>=5.0.2->flask-socketio) (4.4.1)
# Requirement already satisfied: colorama in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from click>=8.1.3->Flask>=0.9->flask-socketio) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\arimax\appdata\local\programs\python\python310\lib\site-packages (from Jinja2>=3.1.2->Flask>=0.9->flask-socketio) (2.1.3)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Import Packages

# %%
import os
from dotenv import load_dotenv
load_dotenv(override=True)

import shutil
import sys
sys.path.append('./utils')

### Uncomment below imports as needed -- make sure that all relevant values and keys in the .env file are properly populated
# from utils import redis_helpers
# from utils import helpers
# from utils import language
# from utils import openai_helpers
# from utils import storage
# from utils import bot_helpers

from utils.env_vars import *

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Activate Cognitive Search Ingestion
# #### First Run - Create Index and Indexer
# ##### Caution: this will destroy any data you might already have in your index

# %%
#### Ingest all knowledge base documents
from utils import cogsearch_helpers

cogsearch_helpers.ingest_kb(container = KB_BLOB_CONTAINER)
# Out:
# Index km-openai-sem Deleted
# Index km-openai-sem created
# Index km-openai Deleted
# Index km-openai created
# Deleted Skillset - km-openai-skills
# Created new Skillset - km-openai-skills
# Deleted Indexer - km-openai-indexer
# Deleted Data Source - km-openai-skills
# Created new Data Source Connection - km-openai-docs
# Created new Indexer - km-openai-indexer
# Running Indexer km-openai-indexer

# %% [markdown]
# ### Activate Form Recognizer Ingestion

# %%
#### Ingest all form documents

from utils import storage
from utils import fr_helpers

fr_helpers.process_forms(in_container = FR_CONTAINER, out_container = OUTPUT_BLOB_CONTAINER)
